# %%
import pandas as pd
inventory_discrepancy = pd.read_csv('inventory_discrepancy.csv', index_col=0)
inventory_discrepancy.head()
# Out:
#   Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 0               BRANCO                     C                 VESTUARIO
# 1                 ROSA                     C                 VESTUARIO
# 2                  NaN                     H        ELETRO-ELETRONICOS
# 3                JEANS                     C                 VESTUARIO
# 4                JEANS                     C                 VESTUARIO
#
#   Retail_Product_Level2Name Retail_Product_Level3Name  \
# 0                        CR                       CRB
# 1                        CY                       CYA
# 2                        HZ                       HZB
# 3                        CY                       CYA
# 4                        CY                       CYC
#
#   Retail_Product_Level4Name                       Retail_Product_Name  \
# 0                      CRBK  CALCINHA CR SLO ELLA ESTAMPADO CINZA P B
# ...

# %%
inventory_discrepancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5179 entries, 0 to 5178
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Retail_Product_Color       2873 non-null   object
#  1   Retail_Product_Level1      3187 non-null   object
#  2   Retail_Product_Level1Name  3187 non-null   object
#  3   Retail_Product_Level2Name  3187 non-null   object
#  4   Retail_Product_Level3Name  3187 non-null   object
#  5   Retail_Product_Level4Name  3187 non-null   object
#  6   Retail_Product_Name        3187 non-null   object
#  7   Retail_Product_SKU         5179 non-null   float64
#  8   Retail_Product_Size        2873 non-null   object
#  9   Retail_Product_Style       3187 non-null   object
#  10  Retail_SOHQTY              5179 non-null   int64
#  11  Retail_CCQTY               5179 non-null   int64
#  12  _merge                     5179 non-null   object
# ...

# %%
inventory_discrepancy.isna().sum()
# Out:
# Retail_Product_Color         2306
# Retail_Product_Level1        1992
# Retail_Product_Level1Name    1992
# Retail_Product_Level2Name    1992
# Retail_Product_Level3Name    1992
# Retail_Product_Level4Name    1992
# Retail_Product_Name          1992
# Retail_Product_SKU              0
# Retail_Product_Size          2306
# Retail_Product_Style         1992
# Retail_SOHQTY                   0
# Retail_CCQTY                    0
# _merge                          0
# diff                            0
# unders                          0
# dtype: int64

# %%
inventory_discrepancy.Retail_Product_Level1.value_counts(dropna=False)
# Out:
# C      2873
# NaN    1992
# W       197
# H       117
# Name: Retail_Product_Level1, dtype: int64

# %%
inventory_discrepancy.Retail_Product_Level1Name.value_counts(dropna=False)
# Out:
# VESTUARIO             2873
# NaN                   1992
# BELEZA                 197
# ELETRO-ELETRONICOS     117
# Name: Retail_Product_Level1Name, dtype: int64

# %%
null = inventory_discrepancy[inventory_discrepancy['Retail_Product_Level1'].isna()]
null
# Out:
#      Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 3187                  NaN                   NaN                       NaN
# 3188                  NaN                   NaN                       NaN
# 3189                  NaN                   NaN                       NaN
# 3190                  NaN                   NaN                       NaN
# 3191                  NaN                   NaN                       NaN
# ...                   ...                   ...                       ...
# 5174                  NaN                   NaN                       NaN
# 5175                  NaN                   NaN                       NaN
# 5176                  NaN                   NaN                       NaN
# 5177                  NaN                   NaN                       NaN
# 5178                  NaN                   NaN                       NaN
#
#      Retail_Product_Level2Name Retail_Product_Level3Name  \
# ...

# %%
inventory_cleaned = inventory_discrepancy[~inventory_discrepancy['Retail_Product_Level1'].isna()]
inventory_cleaned.sample(20)
# Out:
#      Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 1266                JEANS                     C                 VESTUARIO
# 2724                JEANS                     C                 VESTUARIO
# 2553                JEANS                     C                 VESTUARIO
# 795                 VERDE                     C                 VESTUARIO
# 1628                PRETO                     C                 VESTUARIO
# 1841                PRETO                     C                 VESTUARIO
# 47                   AZUL                     C                 VESTUARIO
# 1573                JEANS                     C                 VESTUARIO
# 1473            CHOCOLATE                     C                 VESTUARIO
# 1223                JEANS                     C                 VESTUARIO
# 3001                 BEGE                     C                 VESTUARIO
# 921                 JEANS                     C                 VESTUARIO
# ...

# %%
inventory_cleaned.isna().sum()
# Out:
# Retail_Product_Color         314
# Retail_Product_Level1          0
# Retail_Product_Level1Name      0
# Retail_Product_Level2Name      0
# Retail_Product_Level3Name      0
# Retail_Product_Level4Name      0
# Retail_Product_Name            0
# Retail_Product_SKU             0
# Retail_Product_Size          314
# Retail_Product_Style           0
# Retail_SOHQTY                  0
# Retail_CCQTY                   0
# _merge                         0
# diff                           0
# unders                         0
# dtype: int64

# %%
inventory_cleaned.Retail_Product_Color.value_counts(dropna=False)
# Out:
# JEANS        1170
# PRETO         395
# NaN           314
# ROSA          248
# AZUL          152
# CINZA         150
# BRANCO        136
# VERDE         125
# BEGE           90
# MARROM         67
# CHOCOLATE      66
# VERMELHO       59
# ROXO           41
# DOURADO        38
# VINHO          31
# PINK           16
# PRATA          14
# CAQUI          12
# SORTIDO        12
# AMARELO        11
# LILAS          10
# OFF WHITE       9
# LARANJA         8
# PRATEADO        8
# CHUMBO          4
# MARRON          1
# Name: Retail_Product_Color, dtype: int64

# %%
inventory_cleaned[inventory_cleaned['Retail_Product_Color'].isna()].sample(15)
# Out:
#      Retail_Product_Color Retail_Product_Level1 Retail_Product_Level1Name  \
# 1437                  NaN                     H        ELETRO-ELETRONICOS
# 1526                  NaN                     H        ELETRO-ELETRONICOS
# 512                   NaN                     W                    BELEZA
# 877                   NaN                     W                    BELEZA
# 256                   NaN                     W                    BELEZA
# 2583                  NaN                     H        ELETRO-ELETRONICOS
# 2229                  NaN                     W                    BELEZA
# 1470                  NaN                     H        ELETRO-ELETRONICOS
# 2370                  NaN                     W                    BELEZA
# 785                   NaN                     W                    BELEZA
# 2858                  NaN                     H        ELETRO-ELETRONICOS
# 1738                  NaN                     W                    BELEZA
# ...

# %%
inventory_cleaned.to_csv('inventory_discrepancy_cleaned.csv')
